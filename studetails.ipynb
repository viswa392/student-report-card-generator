# %%
student_id = input("Enter student id = ")
student_name = input("Enter student name = ")

# %%
Tamil = int(input("Enter Tamil mark: "))
English = int(input("Enter English mark: "))
Maths = int(input("Enter Maths mark: "))
Science = int(input("Enter Science mark: "))
Computer = int(input("Enter Computer mark: "))

# %%
student = {
    "student id": student_id,
    "student name": student_name,
    "mark": {
        "Tamil mark": Tamil,
        "English mark": English,
        "Maths mark": Maths,
        "Science mark": Science,
        "Computer mark": Computer
    }
}
print(student)
# Out:
# {'student id': '309', 'student name': 'viswa', 'mark': {'Tamil mark': 80, 'English mark': 76, 'Maths mark': 88, 'Science mark': 77, 'Computer mark': 75}}

# %%
print("\nSubject Marks")
print("Tamil :", student["mark"]["Tamil mark"])
print("English :", student["mark"]["English mark"])
print("Maths :", student["mark"]["Maths mark"])
print("Science :", student["mark"]["Science mark"])
print("Computer :", student["mark"]["Computer mark"])
# Out:
# Subject Marks
# Tamil : 80
# English : 76
# Maths : 88
# Science : 77
# Computer : 75

# %%
total = (
    student["mark"]["Tamil mark"] +
    student["mark"]["English mark"] +
    student["mark"]["Maths mark"] +
    student["mark"]["Science mark"] +
    student["mark"]["Computer mark"]
)

print("Total Marks :", total)
# Out:
# Total Marks : 396

# %%
total = sum(student["mark"].values())

average = round(total / len(student["mark"]), 2)

student["total"] = total
student["average"] = average

print("Total Marks :", student["total"])
print("Average Marks :", student["average"])
# Out:
# Total Marks : 396
# Average Marks : 79.2

# %%
if average >= 90:
    grade = "A+"
elif average >= 80:
    grade = "A"
elif average >= 70:
    grade = "B"
elif average >= 60:
    grade = "C"
elif average >= 50:
    grade = "D"
else:
    grade = "F"

student["grade"] = grade

print("Grade :", student["grade"])
# Out:
# Grade : B

# %%
if (
    student["mark"]["Tamil mark"] >= 35
    and student["mark"]["English mark"] >= 35
    and student["mark"]["Maths mark"] >= 35
    and student["mark"]["Science mark"] >= 35
    and student["mark"]["Computer mark"] >= 35
):
    result = "PASS"
else:
    result = "FAIL"

student["result"] = result
print("Result :", student["result"])
if result == "FAIL":
    grade = "F"
# Out:
# Result : PASS

# %%
print("Total Marks :", student["total"])
print("Average Marks :", student["average"])
print("Grade :", student["grade"])
print("Result :", student["result"])
# Out:
# Total Marks : 396
# Average Marks : 79.2
# Grade : B
# Result : PASS

# %%
print("       STUDENT REPORT CARD")


print("Student ID   :", student["student id"])
print("Student Name :", student["student name"])


print("SUBJECT MARKS")

print("Tamil        :", student["mark"]["Tamil mark"])
print("English      :", student["mark"]["English mark"])
print("Maths        :", student["mark"]["Maths mark"])
print("Science      :", student["mark"]["Science mark"])
print("Computer     :", student["mark"]["Computer mark"])


print("Total Marks  :", student["total"])
print("Average      :", student["average"])
print("Grade        :", student["grade"])
print("Result       :", student["result"])
# Out:
#        STUDENT REPORT CARD
# Student ID   : 309
# Student Name : viswa
# SUBJECT MARKS
# Tamil        : 80
# English      : 76
# Maths        : 88
# Science      : 77
# Computer     : 75
# Total Marks  : 396
# Average      : 79.2
# Grade        : B
# Result       : PASS
